# %% [markdown]
# # Main

# %% [markdown]
# ## Define variables and import the main library

# %%
project_directory = '/data/BIDS-HPC/private/projects/dmi2'
import os, sys
links_dir = os.path.join(project_directory, 'data', 'all_gene_expression_files_in_target', 'links')
annotation_file = os.path.join(project_directory, 'data', 'gencode.v22.annotation.gtf')
sample_sheet_file = os.path.join(project_directory, 'data', 'gdc_sample_sheet.2020-07-02.tsv')
metadata_file = os.path.join(project_directory, 'data', 'metadata.cart.2020-07-02.json')
if os.path.join(project_directory, 'checkout') not in sys.path:
    sys.path.append(os.path.join(project_directory, 'checkout'))
import target_class_lib as tc

# %% [markdown]
# ## Load the data downloaded from the GDC Data Portal

# %%
df_samples, df_counts = tc.load_gdc_data(sample_sheet_file, metadata_file, links_dir)
# Out:
# Reading pickle file /data/BIDS-HPC/private/projects/dmi2/data/gdc_data.pkl...

# %% [markdown]
# ## Calculate the FPKM and FPKM-UQ dataframes, and check them with known values if the needed datafiles are present

# %%
df_counts.shape
# Out:
# (1321, 60483)

# %%
df_fpkm, df_fpkm_uq = tc.get_fpkm(df_counts, annotation_file, df_samples, links_dir)
# Out:
# Reading pickle file /data/BIDS-HPC/private/projects/dmi2/data/fpkm_data.pkl...

# %% [markdown]
# ## Remove from the samples and intensities the samples that correspond to multiple cases (i.e., people)

# %%
df_samples, indexes_to_keep, _ = tc.drop_multiperson_samples(df_samples)
df_counts = df_counts.iloc[indexes_to_keep,:]
df_fpkm = df_fpkm.iloc[indexes_to_keep,:]
df_fpkm_uq = df_fpkm_uq.iloc[indexes_to_keep,:]
# Out:
# Dropping the following samples from the samples table:
#                                             file list index  \
# sample id
# TARGET-30-PANKFE-01A, TARGET-30-PAPUAR-01A             1900
# TARGET-30-PANUKV-01A, TARGET-30-PASUML-01A             3075
# TARGET-30-PAPEAV-01A, TARGET-30-PAPTFZ-01A             3653
# TARGET-30-PASYPX-01A, TARGET-30-PAIXIF-01A             1660
#
#                                                                              counts file name  \
# sample id
# TARGET-30-PANKFE-01A, TARGET-30-PAPUAR-01A  71edd401-29be-401e-b2de-f5fdca3964d2.htseq_cou...
# TARGET-30-PANUKV-01A, TARGET-30-PASUML-01A  d5589fcc-c841-43d5-ae2a-ce5ee0914c7e.htseq_cou...
# TARGET-30-PAPEAV-01A, TARGET-30-PAPTFZ-01A  fa6a16c4-9eb9-4f04-a784-1a84f57cb479.htseq_cou...
# TARGET-30-PASYPX-01A, TARGET-30-PAIXIF-01A  34253522-71e6-480e-a832-95491686d146.htseq_cou...
#
#                                             average base quality  \
# sample id
# TARGET-30-PANKFE-01A, TARGET-30-PAPUAR-01A                  35.0
# TARGET-30-PANUKV-01A, TARGET-30-PASUML-01A                  33.0
# TARGET-30-PAPEAV-01A, TARGET-30-PAPTFZ-01A                  36.0
# TARGET-30-PASYPX-01A, TARGET-30-PAIXIF-01A                  31.0
#
#                                                                          file id  \
# sample id
# TARGET-30-PANKFE-01A, TARGET-30-PAPUAR-01A  d9de5328-2f5d-4915-b322-2b4aa7c5391a
# TARGET-30-PANUKV-01A, TARGET-30-PASUML-01A  936e9a45-d879-4500-9571-7024e5dc053a
# TARGET-30-PAPEAV-01A, TARGET-30-PAPTFZ-01A  99b36164-ff85-4a6b-85de-77bd42aff592
# TARGET-30-PASYPX-01A, TARGET-30-PAIXIF-01A  5ad6072e-b35b-4e62-937d-6c7ab706a346
#
#                                                         project id  \
# sample id
# TARGET-30-PANKFE-01A, TARGET-30-PAPUAR-01A  TARGET-NBL, TARGET-NBL
# TARGET-30-PANUKV-01A, TARGET-30-PASUML-01A  TARGET-NBL, TARGET-NBL
# TARGET-30-PAPEAV-01A, TARGET-30-PAPTFZ-01A  TARGET-NBL, TARGET-NBL
# TARGET-30-PASYPX-01A, TARGET-30-PAIXIF-01A  TARGET-NBL, TARGET-NBL
#
#                                                                        case id  \
# sample id
# TARGET-30-PANKFE-01A, TARGET-30-PAPUAR-01A  TARGET-30-PANKFE, TARGET-30-PAPUAR
# TARGET-30-PANUKV-01A, TARGET-30-PASUML-01A  TARGET-30-PANUKV, TARGET-30-PASUML
# TARGET-30-PAPEAV-01A, TARGET-30-PAPTFZ-01A  TARGET-30-PAPEAV, TARGET-30-PAPTFZ
# TARGET-30-PASYPX-01A, TARGET-30-PAIXIF-01A  TARGET-30-PASYPX, TARGET-30-PAIXIF
#
#                                                              sample type  \
# sample id
# TARGET-30-PANKFE-01A, TARGET-30-PAPUAR-01A  Primary Tumor, Primary Tumor
# TARGET-30-PANUKV-01A, TARGET-30-PASUML-01A  Primary Tumor, Primary Tumor
# TARGET-30-PAPEAV-01A, TARGET-30-PAPTFZ-01A  Primary Tumor, Primary Tumor
# TARGET-30-PASYPX-01A, TARGET-30-PAIXIF-01A  Primary Tumor, Primary Tumor
#
#                                            contamination_error  \
# sample id
# TARGET-30-PANKFE-01A, TARGET-30-PAPUAR-01A                None
# TARGET-30-PANUKV-01A, TARGET-30-PASUML-01A                None
# TARGET-30-PAPEAV-01A, TARGET-30-PAPTFZ-01A                None
# TARGET-30-PASYPX-01A, TARGET-30-PAIXIF-01A                None
#
#                                             proportion_reads_mapped  \
# sample id
# TARGET-30-PANKFE-01A, TARGET-30-PAPUAR-01A                 0.985460
# TARGET-30-PANUKV-01A, TARGET-30-PASUML-01A                 0.951929
# TARGET-30-PAPEAV-01A, TARGET-30-PAPTFZ-01A                 0.994043
# TARGET-30-PASYPX-01A, TARGET-30-PAIXIF-01A                 0.920981
#
#                                             proportion_reads_duplicated  \
# sample id
# TARGET-30-PANKFE-01A, TARGET-30-PAPUAR-01A                          0.0
# TARGET-30-PANUKV-01A, TARGET-30-PASUML-01A                          0.0
# TARGET-30-PAPEAV-01A, TARGET-30-PAPTFZ-01A                          0.0
# TARGET-30-PASYPX-01A, TARGET-30-PAIXIF-01A                          0.0
#
#                                            contamination  \
# sample id
# TARGET-30-PANKFE-01A, TARGET-30-PAPUAR-01A          None
# TARGET-30-PANUKV-01A, TARGET-30-PASUML-01A          None
# TARGET-30-PAPEAV-01A, TARGET-30-PAPTFZ-01A          None
# TARGET-30-PASYPX-01A, TARGET-30-PAIXIF-01A          None
#
#                                             proportion_base_mismatch  \
# sample id
# TARGET-30-PANKFE-01A, TARGET-30-PAPUAR-01A                  0.003681
# TARGET-30-PANUKV-01A, TARGET-30-PASUML-01A                  0.007599
# TARGET-30-PAPEAV-01A, TARGET-30-PAPTFZ-01A                  0.003493
# TARGET-30-PASYPX-01A, TARGET-30-PAIXIF-01A                  0.011965
#
#                                                state  platform  \
# sample id
# TARGET-30-PANKFE-01A, TARGET-30-PAPUAR-01A  released  Illumina
# TARGET-30-PANUKV-01A, TARGET-30-PASUML-01A  released  Illumina
# TARGET-30-PAPEAV-01A, TARGET-30-PAPTFZ-01A  released  Illumina
# TARGET-30-PASYPX-01A, TARGET-30-PAIXIF-01A  released  Illumina
#
#                                             average_read_length  \
# sample id
# TARGET-30-PANKFE-01A, TARGET-30-PAPUAR-01A                101.0
# TARGET-30-PANUKV-01A, TARGET-30-PASUML-01A                100.0
# TARGET-30-PAPEAV-01A, TARGET-30-PAPTFZ-01A                101.0
# TARGET-30-PASYPX-01A, TARGET-30-PAIXIF-01A                103.0
#
#                                                  entity_submitter_id
# sample id
# TARGET-30-PANKFE-01A, TARGET-30-PAPUAR-01A  TARGET-30-PANKFE-01A-01R
# TARGET-30-PANUKV-01A, TARGET-30-PASUML-01A  TARGET-30-PANUKV-01A-01R
# TARGET-30-PAPEAV-01A, TARGET-30-PAPTFZ-01A  TARGET-30-PAPTFZ-01A-01R
# TARGET-30-PASYPX-01A, TARGET-30-PAIXIF-01A  TARGET-30-PAIXIF-01A-01R

# %% [markdown]
# ## Perform exploratory data analysis on the sample labels

# %%
tc.eda_labels(df_samples)
# Out:
# /data/BIDS-HPC/private/projects/dmi2/checkout/target_class_lib.py:563: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   _ = df_samples.hist(ax=ax)
# Non-numeric columns with all unique values (1317 of them), with sample values:
#
#  . counts file name        2d030796-7518-4d42-8c56-d156630b754e.htseq_counts.txt.gz
#  . file id                 cc425bdb-7c42-47a3-bf13-a595564f521d
#  . entity_submitter_id     TARGET-30-PASUYG-01A-01R
#  . sample id               TARGET-30-PASUYG-01A
#
# Non-numeric columns with uniform values:
#
#  . contamination_error     None
#  . contamination           None
#  . state                   released
#  . platform                Illumina
#
# Non-numeric columns with non-unique and non-uniform values:
#
#  . project id              9
#
# TARGET-ALL-P2    519
# TARGET-AML       187
# TARGET-NBL       157
# TARGET-WT        136
# TARGET-ALL-P3    135
# TARGET-OS         88
# TARGET-RT         70
# TARGET-CCSK       13
# TARGET-ALL-P1     12
# Name: project id, dtype: int64
#
#  . case id                 1188
#
# TARGET-15-SJMPAL042946    3
# TARGET-20-PARBIU          2
# TARGET-15-SJMPAL042798    2
# TARGET-20-PAEIKD          2
# TARGET-20-PARYFN          2
#                          ..
# TARGET-15-SJMPAL040030    1
# TARGET-10-PASZIY          1
# TARGET-10-PATWYL          1
# TARGET-10-PARTPW          1
# TARGET-15-SJMPAL043507    1
# Name: case id, Length: 1188, dtype: int64
#
#  . sample type             8
#
# Primary Blood Derived Cancer - Bone Marrow           618
# Primary Tumor                                        438
# Recurrent Blood Derived Cancer - Bone Marrow         117
# Primary Blood Derived Cancer - Peripheral Blood      115
# Solid Tissue Normal                                   12
# Recurrent Tumor                                       12
# Recurrent Blood Derived Cancer - Peripheral Blood      4
# Metastatic                                             1
# Name: sample type, dtype: int64

# %% [markdown]
# ## Plot histograms of the numerical columns of the samples/labels before and after cutoffs are applied, and print out a summary of what was removed

# %%
df_samples, indexes_to_keep = tc.remove_bad_samples(df_samples)
df_counts = df_counts.iloc[indexes_to_keep,:]
df_fpkm = df_fpkm.iloc[indexes_to_keep,:]
df_fpkm_uq = df_fpkm_uq.iloc[indexes_to_keep,:]
# Out:
# /data/BIDS-HPC/private/projects/dmi2/checkout/target_class_lib.py:448: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   ax_hist = df_samples.hist(ax=ax)
# There are 64 bad values in the "average base quality" plot
# There are 61 bad values in the "proportion_base_mismatch" plot
# There are 54 bad values in the "proportion_reads_mapped" plot
# Most bad values are overlapping; taken together, there are 89 bad values
# We should likely use these cutoffs to remove the bad samples; this will only remove 6.8% of the data, leaving 1228 good samples
# See for example the two generated images: the first is the original data with the cutoffs plotted in red, and the second is the filtered data with the cutoffs applied
# /data/BIDS-HPC/private/projects/dmi2/checkout/target_class_lib.py:502: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   _ = df_samples.iloc[valid_ind,:].hist(ax=ax)

# %% [markdown]
# ## Perform exploratory data analysis on the filtered sample labels

# %%
tc.eda_labels(df_samples)
# Out:
# /data/BIDS-HPC/private/projects/dmi2/checkout/target_class_lib.py:563: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   _ = df_samples.hist(ax=ax)
# Non-numeric columns with all unique values (1228 of them), with sample values:
#
#  . counts file name        3846b133-3031-42ff-bd59-027112f36913.htseq_counts.txt.gz
#  . file id                 a3a92f09-bbb8-4177-aaaa-c09b09a033ab
#  . entity_submitter_id     TARGET-30-PASZPI-01A-01R
#  . sample id               TARGET-30-PASZPI-01A
#
# Non-numeric columns with uniform values:
#
#  . contamination_error     None
#  . contamination           None
#  . state                   released
#  . platform                Illumina
#
# Non-numeric columns with non-unique and non-uniform values:
#
#  . project id              9
#
# TARGET-ALL-P2    518
# TARGET-AML       187
# TARGET-NBL       143
# TARGET-WT        136
# TARGET-ALL-P3    135
# TARGET-RT         69
# TARGET-OS         24
# TARGET-CCSK       13
# TARGET-ALL-P1      3
# Name: project id, dtype: int64
#
#  . case id                 1099
#
# TARGET-15-SJMPAL042946    3
# TARGET-20-PAEFGT          2
# TARGET-30-PARHAM          2
# TARGET-50-PAJPDC          2
# TARGET-52-PARRCL          2
#                          ..
# TARGET-10-PANZXZ          1
# TARGET-10-PARPYJ          1
# TARGET-10-PAPEWB          1
# TARGET-30-PAPTFZ          1
# TARGET-15-SJMPAL043507    1
# Name: case id, Length: 1099, dtype: int64
#
#  . sample type             8
#
# Primary Blood Derived Cancer - Bone Marrow           614
# Primary Tumor                                        359
# Recurrent Blood Derived Cancer - Bone Marrow         117
# Primary Blood Derived Cancer - Peripheral Blood      109
# Solid Tissue Normal                                   12
# Recurrent Tumor                                       12
# Recurrent Blood Derived Cancer - Peripheral Blood      4
# Metastatic                                             1
# Name: sample type, dtype: int64

# %% [markdown]
# ## Print some random data for us to spot-check in the files themselves to manually ensure we have a handle on the data arrays

# %%
tc.spot_check_data(df_samples, df_counts, df_fpkm, df_fpkm_uq)
# Out:
# Sample TARGET-20-PARVAI-03A (TARGET-AML, Primary Blood Derived Cancer - Peripheral Blood) should have a counts value of 2 for gene ENSG00000244289.1
# Sample TARGET-10-PASTYT-09B (TARGET-ALL-P2, Primary Blood Derived Cancer - Bone Marrow) should have a counts value of 2 for gene ENSG00000137727.11
# Sample TARGET-10-PAPBCI-09A (TARGET-ALL-P2, Primary Blood Derived Cancer - Bone Marrow) should have a counts value of 8 for gene ENSG00000230721.1
# Sample TARGET-20-PANLKB-09A (TARGET-AML, Primary Blood Derived Cancer - Bone Marrow) should have a counts value of 1 for gene ENSG00000204380.3
# Sample TARGET-15-SJMPAL041117-09A (TARGET-ALL-P3, Primary Blood Derived Cancer - Bone Marrow) should have a FPKM value of 4.600299673839183 for gene ENSG00000217624.2
# Sample TARGET-15-SJMPAL012425-09A (TARGET-ALL-P3, Primary Blood Derived Cancer - Bone Marrow) should have a FPKM value of 2.294975956089495 for gene ENSG00000260060.1
# Sample TARGET-10-PASPPN-09A (TARGET-ALL-P2, Primary Blood Derived Cancer - Bone Marrow) should have a FPKM value of 21.508521476237767 for gene ENSG00000272055.1
# Sample TARGET-20-PANUTB-09A (TARGET-AML, Primary Blood Derived Cancer - Bone Marrow) should have a FPKM value of 82.10074863345295 for gene ENSG00000104904.11
# Sample TARGET-20-PARTAL-04A (TARGET-AML, Recurrent Blood Derived Cancer - Bone Marrow) should have a FPKM-UQ value of 25013.643805712207 for gene ENSG00000248489.1
# Sample TARGET-10-PANUHA-09A (TARGET-ALL-P2, Primary Blood Derived Cancer - Bone Marrow) should have a FPKM-UQ value of 1506392.5996073182 for gene ENSG00000107036.10
# Sample TARGET-20-PARXBT-09A (TARGET-AML, Primary Blood Derived Cancer - Bone Marrow) should have a FPKM-UQ value of 144.13999914524982 for gene ENSG00000134853.10
# Sample TARGET-20-PANDIX-09A (TARGET-AML, Primary Blood Derived Cancer - Bone Marrow) should have a FPKM-UQ value of 817879.8343167378 for gene ENSG00000141582.13

# %% [markdown]
# ## Calculate the TPM using the counts and gene lengths
# Note I've confirmed sufficient equality using TPM calculation using FPKM and FPKM-UQ

# %%
df_tpm = tc.get_tpm(df_counts, annotation_file)
# Out:
# Reading pickle file /data/BIDS-HPC/private/projects/dmi2/data/annotation_dataframe.pkl...

# %%
df_tpm.shape
df_tpm.index = df_tpm.index.str.replace('-', '_')

# %% [markdown]
# ## Add a labels column based on the project id and sample type columns and show the unique values by decreasing frequency

# %%
df_samples['label 1'] = df_samples['project id'] + ', ' + df_samples['sample type']
print(df_samples['label 1'].value_counts())
# Out:
# TARGET-ALL-P2, Primary Blood Derived Cancer - Bone Marrow           379
# TARGET-NBL, Primary Tumor                                           135
# TARGET-WT, Primary Tumor                                            124
# TARGET-AML, Primary Blood Derived Cancer - Bone Marrow              119
# TARGET-ALL-P3, Primary Blood Derived Cancer - Bone Marrow           113
# TARGET-ALL-P2, Primary Blood Derived Cancer - Peripheral Blood       74
# TARGET-ALL-P2, Recurrent Blood Derived Cancer - Bone Marrow          64
# TARGET-RT, Primary Tumor                                             63
# TARGET-AML, Recurrent Blood Derived Cancer - Bone Marrow             40
# TARGET-AML, Primary Blood Derived Cancer - Peripheral Blood          26
# TARGET-OS, Primary Tumor                                             24
# TARGET-CCSK, Primary Tumor                                           13
# TARGET-ALL-P3, Recurrent Blood Derived Cancer - Bone Marrow          12
# TARGET-ALL-P3, Primary Blood Derived Cancer - Peripheral Blood        9
# TARGET-NBL, Recurrent Tumor                                           7
# TARGET-WT, Solid Tissue Normal                                        6
# TARGET-RT, Solid Tissue Normal                                        6
# TARGET-WT, Recurrent Tumor                                            5
# TARGET-ALL-P1, Primary Blood Derived Cancer - Bone Marrow             3
# TARGET-AML, Recurrent Blood Derived Cancer - Peripheral Blood         2
# TARGET-NBL, Recurrent Blood Derived Cancer - Bone Marrow              1
# TARGET-WT, Metastatic                                                 1
# TARGET-ALL-P2, Recurrent Blood Derived Cancer - Peripheral Blood      1
# TARGET-ALL-P3, Recurrent Blood Derived Cancer - Peripheral Blood      1
# Name: label 1, dtype: int64

# %% [markdown]
# ## Run the variance-stabilizing transformation using DESeq2 using this most-detailed set of labels

# %%
X1, y1 = tc.run_vst(df_counts, df_samples['label 1'], project_directory)
# Out:
# Reading pickle file /data/BIDS-HPC/private/projects/dmi2/data/datasets/label_1/vst_transformed_data.pkl...

# %%
df_samples.index = df_samples.index.str.replace('-', '_')

# %%
df_counts.index = df_counts.index.str.replace('-', '_')

# %%
print(X1.shape)
print(y1.shape)
X1=df_tpm
# Out:
# (1228, 60483)
# (1228,)

# %%
X1.index.equals(y1.index)
# Out:
# False

# %%
X1 = X1.sort_index()

# %%
y1 = y1.sort_index()

# %%
X1.index.equals(y1.index)
# Out:
# True

# %% [markdown]
# ## Create and plot PCA and tSNE analyses using the variance-stabilizing-transformed data from DESeq2

# %%
# Perform PCA
import sklearn.decomposition as sk_decomp
pca = sk_decomp.PCA(n_components=10)
pca_res = pca.fit_transform(X1.iloc[:,:500])
#pca_res = pca.fit_transform(X1.iloc[:,:])
print('Top {} PCA explained variance ratios: {}'.format(10, pca.explained_variance_ratio_))
ax = tc.plot_unsupervised_analysis(pca_res, y1)
ax.set_title('PCA - variance-stabilizing transformation')

# Perform tSNE analysis
import sklearn.manifold as sk_manif
tsne = sk_manif.TSNE(n_components=2)
tsne_res = tsne.fit_transform(X1.iloc[:,:500])
#tsne_res = tsne.fit_transform(X1.iloc[:,:])
ax = tc.plot_unsupervised_analysis(tsne_res, y1)
ax.set_title('tSNE - variance-stabilizing transformation')
# Out:
# Top 10 PCA explained variance ratios: [0.51993579 0.16092788 0.11778646 0.05516426 0.04217872 0.02374276
#  0.01139407 0.01041339 0.00877125 0.00721589]
# Text(0.5, 1.0, 'tSNE - variance-stabilizing transformation')

# %% [markdown]
# From the above tSNE plot, we find many interesting things, e.g.:
#
# * ALL is spread out in multiple places (all oranges/yellows and early greens), into four main clusters; in particular:
#   * ALL/P2/PBDC (both /BM and /PB) is located in three of them
#   * ALL/P2/RBDC (i.e., /BM) is basically isolated to one of them
#   * ALL/P3 is basically in the fourth cluster
#   * Note that even though ALL/P3 is supposed to be the "ambiguously myeloid" one (ALAL, acute leukemia of ambiguous lineage), it is primarily ALL/P2 that seems to sometimes be confused with AML
# * AML has its own single cluster
# * There are some ALL in an AML cluster and vice versa, and the two corresponding clusters are near each other
# * CCSK is very tightly clustered
# * NBL has its own cluster, with one RT instance that may be misclassified
# * OS is tightly clustered, except for two samples in WT, which may indicate that they are misclassified
# * Aside from the one possibly misclassified RT, they are all solidly clustered
# * WT is clustered together
# * The two normal species are very tightly clustered together
# * Note the three kidney tumor types (RT, WT, CCSK) are relatively close together (and are also close to OS and normal)

# %% [markdown]
# ## Based on the above observations, make a new set of more sensible labels
#
# See comments in each line in the following code block

# %%
df_samples['label 2'] = df_samples['label 1'] # initialize the new label (2) to the original, most-detailed label (1)
df_samples['label 2'][df_samples['label 2'].str.contains('normal', case=False, regex=False)] = 'TARGET-Normal' # set to "TARGET-Normal" any label including "normal" in its original name
df_samples['label 2'] = df_samples['label 2'].str.split(pat=', ', expand=True)[0] # otherwise, just set the label to the project ID (see definition of 'label 1' above)
df_samples['label 2'] = df_samples['label 2'].str.split(pat='-', expand=True)[1] # finally, at the same time, both remove "TARGET-" from the labels and, for ALL, remove "-PX", where X={1,2,3}
print(df_samples['label 2'].value_counts()) # print the final labels counts
# Out:
# ALL       656
# AML       187
# NBL       143
# WT        130
# RT         63
# OS         24
# CCSK       13
# Normal     12
# Name: label 2, dtype: int64
# <ipython-input-22-c46653d87a5f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_samples['label 2'][df_samples['label 2'].str.contains('normal', case=False, regex=False)] = 'TARGET-Normal' # set to "TARGET-Normal" any label including "normal" in its original name

# %% [markdown]
# ## Re-label the unsupervised plots above, just as a quick check of our new labeling scheme

# %%
# Define the new labels
y = df_samples['label 2'].copy()
y.index = y.index.str.replace('-', '_')
y = y.loc[y1.index] # order them the same way as the PCA/tSNE results we already calculated

# Redo the plots, with appropriate sorting so that the labels are in alphabetical order
sorting_indexes = y.to_numpy().argsort(axis=0)
ax = tc.plot_unsupervised_analysis(pca_res[sorting_indexes,:], y.iloc[sorting_indexes])
ax.set_title('PCA - variance-stabilizing transformation - with new labels')
ax = tc.plot_unsupervised_analysis(tsne_res[sorting_indexes,:], y.iloc[sorting_indexes])
ax.set_title('tSNE - variance-stabilizing transformation - with new labels')
# Out:
# Text(0.5, 1.0, 'tSNE - variance-stabilizing transformation - with new labels')

# %% [markdown]
# Note that had we not previously plotted the most detailed set of labels, we would have been left forever wondering why the two distinct clusters of AML data.
#
# ## Now actually run the variance-stabilizing transformation using DESeq2 on the re-labeled dataset

# %%
X2, y2 = tc.run_vst(df_counts, df_samples['label 2'], project_directory)
# Out:
# Reading pickle file /data/BIDS-HPC/private/projects/dmi2/data/datasets/label_2/vst_transformed_data.pkl...

# %%
#Revert to TPM
X2 = df_tpm

# %%
X2 = X2.sort_index()

# %%
y2 = y2.sort_index()

# %%
X2.index.equals(y2.index)
# Out:
# True

# %% [markdown]
# ## Run PCA and tSNE on the new dataset

# %%
# Perform PCA
import sklearn.decomposition as sk_decomp
pca = sk_decomp.PCA(n_components=10)
pca_res = pca.fit_transform(X2.iloc[:,:500])
print('Top {} PCA explained variance ratios: {}'.format(10, pca.explained_variance_ratio_))
ax = tc.plot_unsupervised_analysis(pca_res, y2)
ax.set_title('PCA - variance-stabilizing transformation')

# Perform tSNE analysis
import sklearn.manifold as sk_manif
tsne = sk_manif.TSNE(n_components=2)
tsne_res = tsne.fit_transform(X2.iloc[:,:500])
ax = tc.plot_unsupervised_analysis(tsne_res, y2)
ax.set_title('tSNE - variance-stabilizing transformation')
# Out:
# Top 10 PCA explained variance ratios: [0.51993579 0.16092788 0.11778646 0.05516426 0.04217872 0.02374276
#  0.01139407 0.01041339 0.00877125 0.00721589]
# Text(0.5, 1.0, 'tSNE - variance-stabilizing transformation')

# %% [markdown]
# ## Create a figure helping to explore the extent of sampling each unique label in the dataset (i.e., each group)

# %%
#fig = tc.explore_sample_size(X2, y2, tsne_res, n_range=range(100,601,100))
fig = tc.explore_sample_size(X2, y2, tsne_res, n_range=[1,3,12,50,100,600])
#fig.savefig(os.path.join(project_directory, 'data', 'exploring_sample_size_100_601_100.png'), facecolor='w', dpi=150)

# %% [markdown]
# ## Run some random forest classification models on the data, saving the results and plotting the accuracies of the models on the entire input datasets

# %%
# Get a reasonable set of sample sizes
possible_n = [x for x in range(1,13)] + [x for x in range(15,46,5*2)] + [x for x in range(50,101,10*2)]

# Determine the samples of just particular types
nbl_or_normal_samples = (y2=='NBL').to_numpy() | (y2=='Normal').to_numpy() # get samples that are NBL or Normal
aml_or_normal_samples = (y2=='AML').to_numpy() | (y2=='Normal').to_numpy() # get samples that are AML or Normal

# Generate the random forest classification models
accuracies, possible_n, rnd_clf_holder = tc.generate_random_forest_models(X2, y2, project_directory, 'tpm_all_classes', ntrials=30, possible_n=possible_n) # all data
accuracies_nbl, possible_n_nbl, rnd_clf_holder_nbl = tc.generate_random_forest_models(X2.iloc[nbl_or_normal_samples,:], y2.iloc[nbl_or_normal_samples], project_directory, 'tpm_nbl_vs_normal', possible_n=possible_n[-10:], ntrials=30) # just NBL/Normal
accuracies_aml, possible_n_aml, rnd_clf_holder_aml = tc.generate_random_forest_models(X2.iloc[aml_or_normal_samples,:], y2.iloc[aml_or_normal_samples], project_directory, 'tpm_aml_vs_normal', possible_n=possible_n[-10:], ntrials=30) # just AML/Normal

# Plot the accuracy vs. sample size for each study type
tc.plot_accuracy_vs_sample_size(accuracies, possible_n, 'all classes')
tc.plot_accuracy_vs_sample_size(accuracies_nbl, possible_n_nbl, 'NBL vs. normal')
tc.plot_accuracy_vs_sample_size(accuracies_aml, possible_n_aml, 'AML vs. normal')

print('Note a random model would get an accuracy score of 0.125')
# Out:
# On trial 1 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 2 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 3 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 4 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 5 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 6 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 7 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 8 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 9 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 10 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 11 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 12 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 13 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 14 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 15 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 16 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 17 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 18 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 19 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 20 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 21 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 22 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 23 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 24 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 25 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 26 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 27 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 28 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 29 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# On trial 30 of 30...
#   On sample size 1 of 19 (n=1)...
#   On sample size 2 of 19 (n=2)...
#   On sample size 3 of 19 (n=3)...
#   On sample size 4 of 19 (n=4)...
#   On sample size 5 of 19 (n=5)...
#   On sample size 6 of 19 (n=6)...
#   On sample size 7 of 19 (n=7)...
#   On sample size 8 of 19 (n=8)...
#   On sample size 9 of 19 (n=9)...
#   On sample size 10 of 19 (n=10)...
#   On sample size 11 of 19 (n=11)...
#   On sample size 12 of 19 (n=12)...
#   On sample size 13 of 19 (n=15)...
#   On sample size 14 of 19 (n=25)...
#   On sample size 15 of 19 (n=35)...
#   On sample size 16 of 19 (n=45)...
#   On sample size 17 of 19 (n=50)...
#   On sample size 18 of 19 (n=70)...
#   On sample size 19 of 19 (n=90)...
# Creating pickle file /data/BIDS-HPC/private/projects/dmi2/data/all_classes.pkl...
# On trial 1 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 2 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 3 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 4 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 5 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 6 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 7 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 8 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 9 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 10 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 11 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 12 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 13 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 14 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 15 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 16 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 17 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 18 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 19 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 20 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 21 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 22 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 23 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 24 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 25 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 26 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 27 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 28 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 29 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 30 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# Creating pickle file /data/BIDS-HPC/private/projects/dmi2/data/nbl_vs_normal.pkl...
# On trial 1 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 2 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 3 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 4 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 5 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 6 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 7 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 8 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 9 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 10 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 11 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 12 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 13 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 14 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 15 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 16 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 17 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 18 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 19 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 20 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 21 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 22 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 23 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 24 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 25 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 26 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 27 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 28 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 29 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# On trial 30 of 30...
#   On sample size 1 of 10 (n=10)...
#   On sample size 2 of 10 (n=11)...
#   On sample size 3 of 10 (n=12)...
#   On sample size 4 of 10 (n=15)...
#   On sample size 5 of 10 (n=25)...
#   On sample size 6 of 10 (n=35)...
#   On sample size 7 of 10 (n=45)...
#   On sample size 8 of 10 (n=50)...
#   On sample size 9 of 10 (n=70)...
#   On sample size 10 of 10 (n=90)...
# Creating pickle file /data/BIDS-HPC/private/projects/dmi2/data/aml_vs_normal.pkl...
# Note a random model would get an accuracy score of 0.125

# %% [markdown]
# ## Determine the genes in decreasing order of average feature importance

# %%
# At least for the time being, this step takes a few minutes
important_genes = tc.calculate_average_feature_importance(X2.columns, rnd_clf_holder, num_last_sample_sizes=10)
important_genes_nbl = tc.calculate_average_feature_importance(X2.columns, rnd_clf_holder_nbl, num_last_sample_sizes=10)
important_genes_aml = tc.calculate_average_feature_importance(X2.columns, rnd_clf_holder_aml, num_last_sample_sizes=10)

# %% [markdown]
# ## Print the top differentiating genes in each study

# %%
print('\nAll data\n', important_genes[:20])
print('\nNBL vs. normal\n', important_genes_nbl[:20])
print('\nAML vs. normal\n', important_genes_aml[:20])
# Out:
# All data
#                  place  norm_score  num_in_rank  raw_score  original score
# ENSG00000164853     1    1.000000            1   0.000825        0.000825
# ENSG00000226519     2    0.933974            1   0.000770        0.000770
# ENSG00000137745     3    0.897437            1   0.000740        0.000740
# ENSG00000132970     4    0.870049            1   0.000717        0.000717
# ENSG00000139656     5    0.867737            1   0.000716        0.000716
# ENSG00000219159     6    0.818146            1   0.000675        0.000675
# ENSG00000111432     7    0.802536            1   0.000662        0.000662
# ENSG00000185624     8    0.756434            1   0.000624        0.000624
# ENSG00000235180     9    0.742657            1   0.000612        0.000612
# ENSG00000157227    10    0.740749            1   0.000611        0.000611
# ENSG00000150551    11    0.735155            1   0.000606        0.000606
# ENSG00000232835    12    0.733462            1   0.000605        0.000605
# ENSG00000172061    13    0.726507            1   0.000599        0.000599
# ENSG00000230838    14    0.726016            1   0.000599        0.000599
# ENSG00000099956    15    0.712148            1   0.000587        0.000587
# ENSG00000067840    16    0.707372            1   0.000583        0.000583
# ENSG00000185551    17    0.700667            1   0.000578        0.000578
# ENSG00000128482    18    0.700446            1   0.000578        0.000578
# ENSG00000125872    19    0.697426            1   0.000575        0.000575
# ENSG00000233919    20    0.690520            1   0.000569        0.000569
#
# NBL vs. normal
#                  place  norm_score  num_in_rank  raw_score  original score
# ENSG00000225366   t-1    1.000000            2   0.000633        0.000633
# ENSG00000196767   t-1    1.000000            2   0.000633        0.000633
# ENSG00000059588   t-2    0.894737            5   0.000567        0.000567
# ENSG00000008294   t-2    0.894737            5   0.000567        0.000567
# ENSG00000010295   t-2    0.894737            5   0.000567        0.000567
# ENSG00000137094   t-2    0.894737            5   0.000567        0.000567
# ENSG00000071859   t-2    0.894737            5   0.000567        0.000567
# ENSG00000134824   t-3    0.842105            6   0.000533        0.000533
# ENSG00000160117   t-3    0.842105            6   0.000533        0.000533
# ENSG00000198914   t-3    0.842105            6   0.000533        0.000533
# ENSG00000110436   t-3    0.842105            6   0.000533        0.000533
# ENSG00000170260   t-3    0.842105            6   0.000533        0.000533
# ENSG00000108830   t-3    0.842105            6   0.000533        0.000533
# ENSG00000249601   t-4    0.789474           20   0.000500        0.000500
# ENSG00000077080   t-4    0.789474           20   0.000500        0.000500
# ENSG00000164082   t-4    0.789474           20   0.000500        0.000500
# ENSG00000145626   t-4    0.789474           20   0.000500        0.000500
# ENSG00000231305   t-4    0.789474           20   0.000500        0.000500
# ENSG00000100439   t-4    0.789474           20   0.000500        0.000500
# ENSG00000115616   t-4    0.789474           20   0.000500        0.000500
#
# AML vs. normal
#                  place  norm_score  num_in_rank  raw_score  original score
# ENSG00000196196     1    1.000000            1   0.000567        0.000567
# ENSG00000143248     2    0.941176            1   0.000533        0.000533
# ENSG00000112902   t-3    0.823529            2   0.000467        0.000467
# ENSG00000104427   t-3    0.823529            2   0.000467        0.000467
# ENSG00000077063   t-4    0.764706           11   0.000433        0.000433
# ENSG00000263432   t-4    0.764706           11   0.000433        0.000433
# ENSG00000232888   t-4    0.764706           11   0.000433        0.000433
# ENSG00000278934   t-4    0.764706           11   0.000433        0.000433
# ENSG00000207744   t-4    0.764706           11   0.000433        0.000433
# ENSG00000150938   t-4    0.764706           11   0.000433        0.000433
# ENSG00000100417   t-4    0.764706           11   0.000433        0.000433
# ENSG00000118785   t-4    0.764706           11   0.000433        0.000433
# ENSG00000138771   t-4    0.764706           11   0.000433        0.000433
# ENSG00000108187   t-4    0.764706           11   0.000433        0.000433
# ENSG00000237172   t-4    0.764706           11   0.000433        0.000433
# ENSG00000137203   t-5    0.705882           23   0.000400        0.000400
# ENSG00000168743   t-5    0.705882           23   0.000400        0.000400
# ENSG00000177427   t-5    0.705882           23   0.000400        0.000400
# ENSG00000197859   t-5    0.705882           23   0.000400        0.000400
# ENSG00000240096   t-5    0.705882           23   0.000400        0.000400

# %% [markdown]
# ## Notes
#
# * Study feature importance (i.e., which genes matter the most) more closely, both between all classes and between pairs of important classes, e.g., NBL vs. normal
# * Run differential expression analyses using DESeq2 to confirm/deny the feature importance analysis here
# * Run the same models on the more detailed set of labels (i.e., more detailed design), where confusion matrices would help elucidate how the model does on the different classes, also possibly seeing if there's any correlation with survival, particularly in the ALL groups
# * Implement bagging in the random forest model prediction above since I run multiple trials of random forest models
# * See [scikit-learn random forest documentation](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html#sklearn.ensemble.RandomForestClassifier.feature_importances_) for note on how to improve upon feature importances
#   * Also tweaking the random forest model hyperparameters may help, e.g., selection of features at each node
#   * Further, read resources [like this](https://machinelearningmastery.com/bagging-and-random-forest-for-imbalanced-classification/) to help understand how to best attack imbalanced datasets using random forest
# * Potentially run TC1 (supervised deep learning) or P1B1 (autoencoder, unsupervised deep learning)
# * Possible overall goals:
#   * Determine the genes that best differentiate between cancer types and deeper classes
#   * Test supervised learning using new samples, also seeing "See the 'Data quality assessment' section of the vignette for strategies to see if new samples are sufficiently similar to previous datasets." Ensure I can reproduce the VST-transformed data using the supervised R functions I wrote.
# * Useful links:
#   * [DESeq2 guide](http://bioconductor.org/packages/devel/bioc/vignettes/DESeq2/inst/doc/DESeq2.html)
#   * [RNA-Seq workflow](http://master.bioconductor.org/packages/release/workflows/html/rnaseqGene.html)
# * Another potential next step is to write up these results
# * Based on cursory results changing num_last_sample_sizes to 1, the rankings of at least the promising genes I noted in AML and NBL seem to change a lot. We'd have to justify how we chose the sample sizes that we did. For the time being I should probably trust num_last_sample_sizes set to 10 as I had thought would be best previously, as I chose that based on the stability of the plots. Fortunately, that seems to give better results at least for the two promising genes I noted. Further exploration was always necessary.

# %% [markdown]
# ## To-do
#
# * Add notes from my last email and Yu's response to here
# * To responsd to Yu: What version of the genome are you using? E.g., ENSG00000229164 (their #17 gene, TRAC) isn’t even in GRCh38. Will results change if align against more current version, at least that that GDC uses? There are also old-looking gene names in their list. This appears to correspond to 27 Feb 2014 at latest.
#     * Note that GDC isn’t much better (10.2014, 22, N, 03.2015, GRCh38, 22) but at least it’s GRCh38?
# * Compare where their top genes rank in our list and vice versa
#   * Come up with a scoring system for their data, probably using negative log and normalizing to the best value
# * Address and respond to the rest of Yu's email

# %% [markdown]
# # Scratch
